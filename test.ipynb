# %%
from emoji import emojize, demojize
reactions = (
    '1️⃣', '2️⃣', '3️⃣', '4️⃣', '5️⃣',
    '6️⃣', '7️⃣', '8️⃣', '9️⃣', '🔟',
)

vals = ('a', 'b')

emojize(', '.join([f':keycap_{v}:' for v in vals]))
# Out:
# '1️⃣, 1️⃣'

# %%
from typing import NamedTuple

command = (NamedTuple('Command', name=str))('reaction_poll')

print(command)
# Out:
# C(name='reaction_poll')
